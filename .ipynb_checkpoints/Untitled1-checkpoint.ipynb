# %% [markdown]
# # PROYECTO

# %% [markdown]
# ## IMPORTAR LIBRERÍAS

# %%
import pandas as pd
import firebase_admin
from firebase_admin import db

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb
from sklearn.cluster import KMeans
from sklearn.metrics import pairwise_distances_argmin_min
from mpl_toolkits.mplot3d import Axes3D

# %%
plt.rcParams['figure.figsize'] = (16,9)
plt.style.use('ggplot')
dataframe = pd.read_csv(r"entradasBombillo.csv", sep = ';')
dataframe.head()
# Out:
#   Observaciones  ALFA   BETA  GAMMA  DELTA  EPSILON  ZETA    ETA  THETA  IOTA  \
# 0          Sara   0.0   3.21   0.00   4.29    12.02     0   5.00    2.5     0
# 1        Emilio   0.0   9.58   0.00  22.14    36.58     0  18.33   37.5    45
# 2       Alfredo   0.0  17.36   0.00  30.00    36.67     0  20.00    0.0    30
# 3        Juanca   0.0   0.00   0.00   0.00    14.05     0   0.00    0.0     0
# 4         Salim   0.0   3.57  17.14  15.00    35.00     0   0.00    0.0    15
#
#    KAPPA  LAMBDA  MU  NU  XI
# 0  15.00       0   5  15  24
# 1   5.00       0   1  30  30
# 2  36.67      15   0  45  32
# 3  10.00       0   0   0  12
# 4  40.00       0   0  30  36

# %%
dataframe.hist()
plt.show()

# %%
sb.pairplot(dataframe.dropna(), height = 4, vars = ["ALFA", "GAMMA", "EPSILON"], kind= 'scatter')

# %% [markdown]
# "ALFA", "BETA", "GAMMA", "DELTA", "EPSILON", "ZETA", "ETA", "THETA", "IOTA", "KAPPA", "LAMBDA", "MU", "NU", "XI"

# %%
x = np.array(dataframe[["ALFA", "BETA", "GAMMA", "DELTA", "EPSILON", "ZETA", "ETA", "THETA", "IOTA", "KAPPA", "LAMBDA", "MU", "NU", "XI"]])
x.shape
# Out:
# (7, 14)

# %%
kmeans = KMeans(n_clusters=3).fit(x)
centroids = kmeans.cluster_centers_
print(centroids)
# Out:
# [[ 0.     13.47    0.     26.07   36.625   0.     19.165  18.75   37.5
#   20.835   7.5     0.5    37.5    31.    ]
#  [ 0.      3.935   4.285   4.8225 26.0475  0.      3.75    0.625   3.75
#   28.75    0.      1.25   15.     30.    ]
#  [ 9.06   26.15   43.12   46.88   52.5    15.     25.     60.     60.
#   60.     20.     60.     60.     60.    ]]

# %%
# Predicting the clusters
labels = kmeans.predict(x)
# Getting the cluster centers
C = kmeans.cluster_centers_
colores=['red','green','blue']
asignar=[]
for row in labels:
    asignar.append(colores[row])
 
fig = plt.figure()
ax = Axes3D(fig)
ax.scatter(x[:, 0], x[:, 1], x[:, 2], c=asignar,s=60)
ax.scatter(C[:, 0], C[:, 1], C[:, 2], marker='*', c=colores, s=1000)
# Out:
# C:\Users\sdaza\AppData\Local\Temp/ipykernel_22900/2772704713.py:11: MatplotlibDeprecationWarning: Axes3D(fig) adding itself to the figure is deprecated since 3.4. Pass the keyword argument auto_add_to_figure=False and use fig.add_axes(ax) to suppress this warning. The default value of auto_add_to_figure will change to False in mpl3.5 and True values will no longer work in 3.6.  This is consistent with other Axes classes.
#   ax = Axes3D(fig)

# %%
cred_obj = firebase_admin.credentials.Certificate('cirat-se-ia-firebase-adminsdk-i2qec-1889f0b4e7.json')

default_app = firebase_admin.initialize_app(cred_obj, {'databaseURL':'https://cirat-se-ia-default-rtdb.firebaseio.com'})

# %%
ref = db.reference("/baseDatos")
leer = ref.get()
print(leer)
# Out:
# {'ALFA': 6, 'BETA': 25, 'DELTA': 30, 'EPSILON': 50, 'ETA': 25, 'GAMMA': 20, 'IOTA': 20, 'KAPPA': 40, 'LAMBDA': 20, 'MU': 30, 'NU': 40, 'THETA': 40, 'XI': 40, 'ZETA': 5}

# %%
nuev=list(leer.values())
nuev
# Out:
# [6, 25, 30, 50, 25, 20, 20, 40, 20, 30, 40, 40, 40, 5]

# %%
nuev.insert(0, "N")
nuev
# Out:
# ['N', 6, 25, 30, 50, 25, 20, 20, 40, 20, 30, 40, 40, 40, 5]

# %%
dataframe.loc[7]=nuev
dataframe
# Out:
#   Observaciones  ALFA   BETA  GAMMA  DELTA  EPSILON  ZETA    ETA  THETA  IOTA  \
# 0          Sara  0.00   3.21   0.00   4.29    12.02     0   5.00    2.5     0
# 1        Emilio  0.00   9.58   0.00  22.14    36.58     0  18.33   37.5    45
# 2       Alfredo  0.00  17.36   0.00  30.00    36.67     0  20.00    0.0    30
# 3        Juanca  0.00   0.00   0.00   0.00    14.05     0   0.00    0.0     0
# 4         Salim  0.00   3.57  17.14  15.00    35.00     0   0.00    0.0    15
# 5      Santiago  9.06  26.15  43.12  46.88    52.50    15  25.00   60.0    60
# 6        Eduard  0.00   8.96   0.00   0.00    43.12     0  10.00    0.0     0
# 7             N  6.00  25.00  30.00  50.00    25.00    20  20.00   40.0    20
#
#    KAPPA  LAMBDA  MU  NU  XI
# 0  15.00       0   5  15  24
# 1   5.00       0   1  30  30
# 2  36.67      15   0  45  32
# 3  10.00       0   0   0  12
# 4  40.00       0   0  30  36
# 5  60.00      20  60  60  60
# 6  50.00       0   0  15  48
# ...

# %%
x = np.array(dataframe[["ALFA", "BETA", "GAMMA", "DELTA", "EPSILON", "ZETA", "ETA", "THETA", "IOTA", "KAPPA", "LAMBDA", "MU", "NU", "XI"]])
kmeans = KMeans(n_clusters=3).fit(x)

# %%
# Predicting the clusters
labels = kmeans.predict(x)
# Getting the cluster centers
C = kmeans.cluster_centers_
colores=['red','green','blue']
asignar=[]
for row in labels:
    asignar.append(colores[row])
 
fig = plt.figure()
ax = Axes3D(fig)
ax.scatter(x[:, 0], x[:, 1], x[:, 2], c=asignar,s=60)
ax.scatter(C[:, 0], C[:, 1], C[:, 2], marker='*', c=colores, s=1000)
# Out:
# C:\Users\sdaza\AppData\Local\Temp/ipykernel_22900/2772704713.py:11: MatplotlibDeprecationWarning: Axes3D(fig) adding itself to the figure is deprecated since 3.4. Pass the keyword argument auto_add_to_figure=False and use fig.add_axes(ax) to suppress this warning. The default value of auto_add_to_figure will change to False in mpl3.5 and True values will no longer work in 3.6.  This is consistent with other Axes classes.
#   ax = Axes3D(fig)

# %%
nuev.remove('N')
X_new = np.array([nuev])
X_new
# Out:
# array([[ 6, 25, 30, 50, 25, 20, 20, 40, 20, 30, 40, 40, 40,  5]])

# %%
new_labels = kmeans.predict(X_new)
new_labels
# Out:
# array([1])

# %%
if new_labels == 0:
    print("Usuario en grupo 0. Las recomendaciones se harán según su consumo mensual.")
elif new_labels == 1:
    print("Usuario en grupo 1. Las recomendaciones se harán según su consumo mensual.")
else:
    print("Usuario en grupo 2. Las recomendaciones se harán para reducir el consumo del usuario.")
# Out:
# Usuario en grupo 1. Las recomendaciones se harán según su consumo mensual.

# %%
copy =  pd.DataFrame()
copy['Observaciones']=dataframe['Observaciones'].values
copy['label'] = labels;
cantidadGrupo =  pd.DataFrame()
cantidadGrupo['color']=colores
cantidadGrupo['cantidad']=copy.groupby('label').size()
cantidadGrupo
# Out:
#    color  cantidad
# 0    red         6
# 1  green         1
# 2   blue         1
